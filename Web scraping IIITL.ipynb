# %%
pip install html2text requests beautifulsoup4 langchain langchain_openai
# Out:
# Collecting html2text
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Requirement already satisfied: requests in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (2.28.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (4.12.2)
# Collecting langchain
#   Downloading langchain-0.1.9-py3-none-any.whl (816 kB)
#                                               0.0/817.0 kB ? eta -:--:--
#      ------------                           276.5/817.0 kB 5.7 MB/s eta 0:00:01
#      ------------------------------------  809.0/817.0 kB 10.1 MB/s eta 0:00:01
#      ------------------------------------  809.0/817.0 kB 10.1 MB/s eta 0:00:01
#      -------------------------------------- 817.0/817.0 kB 5.7 MB/s eta 0:00:00
# Collecting langchain_openai
#   Downloading langchain_openai-0.0.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.27-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      ------------------                       1.0/2.1 MB 20.5 MB/s eta 0:00:01
#      ------------------------------           1.6/2.1 MB 16.7 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 18.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 12.0 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
#                                               0.0/365.3 kB ? eta -:--:--
#      ------------------------------------- 365.3/365.3 kB 23.7 MB/s eta 0:00:00
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.21 (from langchain)
#   Downloading langchain_community-0.0.22-py3-none-any.whl (1.7 MB)
#                                               0.0/1.7 MB ? eta -:--:--
#      ---------------------                    0.9/1.7 MB 19.8 MB/s eta 0:00:01
#      ---------------------------------------  1.7/1.7 MB 21.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 18.2 MB/s eta 0:00:00
# Collecting langchain-core<0.2,>=0.1.26 (from langchain)
#   Downloading langchain_core-0.1.26-py3-none-any.whl (246 kB)
#                                               0.0/246.4 kB ? eta -:--:--
#      ------------------------------------- 246.4/246.4 kB 14.8 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain)
#   Downloading langsmith-0.1.5-py3-none-any.whl (61 kB)
#                                               0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.24.3)
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#                                               0.0/394.8 kB ? eta -:--:--
#      ------------------------------------- 394.8/394.8 kB 12.4 MB/s eta 0:00:00
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting openai<2.0.0,>=1.10.0 (from langchain_openai)
#   Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#                                               0.0/226.7 kB ? eta -:--:--
#      ------------------------------------- 226.7/226.7 kB 14.4 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.5.2 (from langchain_openai)
#   Downloading tiktoken-0.6.0-cp311-cp311-win_amd64.whl (798 kB)
#                                               0.0/798.7 kB ? eta -:--:--
#      ------------------------------------  788.5/798.7 kB 24.3 MB/s eta 0:00:01
#      ------------------------------------- 798.7/798.7 kB 16.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl (50 kB)
#                                               0.0/50.5 kB ? eta -:--:--
#      ---------------------------------------- 50.5/50.5 kB 2.5 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl (76 kB)
#                                               0.0/76.7 kB ? eta -:--:--
#      ---------------------                    41.0/76.7 kB ? eta -:--:--
#      ---------------------------------------- 76.7/76.7 kB 4.2 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#                                               0.0/49.4 kB ? eta -:--:--
#      ---------------------------------        41.0/49.4 kB ? eta -:--:--
#      -------------------------------------- 49.4/49.4 kB 622.4 kB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.3)
# Requirement already satisfied: anyio<5,>=3 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.2,>=0.1.26->langchain) (3.6.2)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2,>=0.1.26->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#                                               0.0/53.0 kB ? eta -:--:--
#      ---------------------------------------- 53.0/53.0 kB 2.9 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.10.0->langchain_openai)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.10.0->langchain_openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#                                               0.0/75.6 kB ? eta -:--:--
#      ---------------------------------------- 75.6/75.6 kB ? eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain_openai) (4.8.0)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic<3,>=1->langchain)
#   Downloading pydantic_core-2.16.2-cp311-none-win_amd64.whl (1.9 MB)
#                                               0.0/1.9 MB ? eta -:--:--
#      ---------------                          0.7/1.9 MB 22.8 MB/s eta 0:00:01
#      -------------------                      0.9/1.9 MB 11.8 MB/s eta 0:00:01
#      -------------------------------------    1.8/1.9 MB 14.3 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 13.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 10.1 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp311-cp311-win_amd64.whl (292 kB)
#                                               0.0/292.8 kB ? eta -:--:--
#                                               0.0/292.8 kB ? eta -:--:--
#      ------------------------------------- 292.8/292.8 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1,>=0.5.2->langchain_openai) (2023.10.3)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#                                               0.0/77.8 kB ? eta -:--:--
#      ---------------------------------------- 77.8/77.8 kB 4.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain_openai)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: colorama in c:\users\prateek mohan\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain_openai) (0.4.6)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, pydantic-core, packaging, mypy-extensions, multidict, jsonpatch, html2text, h11, greenlet, frozenlist, distro, annotated-types, yarl, typing-inspect, tiktoken, SQLAlchemy, pydantic, marshmallow, httpcore, aiosignal, langsmith, httpx, dataclasses-json, aiohttp, openai, langchain-core, langchain_openai, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
# Successfully installed SQLAlchemy-2.0.27 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 dataclasses-json-0.6.4 distro-1.9.0 frozenlist-1.4.1 greenlet-3.0.3 h11-0.14.0 html2text-2020.1.16 httpcore-1.0.4 httpx-0.27.0 jsonpatch-1.33 langchain-0.1.9 langchain-community-0.0.22 langchain-core-0.1.26 langchain_openai-0.0.7 langsmith-0.1.5 marshmallow-3.20.2 multidict-6.0.5 mypy-extensions-1.0.0 openai-1.12.0 packaging-23.2 pydantic-2.6.1 pydantic-core-2.16.2 tenacity-8.2.3 tiktoken-0.6.0 typing-inspect-0.9.0 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import html2text

def extract_html_from_url(url):
    try:
        # Fetch HTML content from the URL using requests
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad responses (4xx and 5xx)

        # Parse HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        excluded_tagNames = ['footer', 'nav']
        # Exclude elements with class names 'footer' and 'navbar'
        excluded_tags = excluded_tagNames or []  # Default to an empty list if not provided
        for tag_name in excluded_tags:
            for unwanted_tag in soup.find_all(tag_name):
                unwanted_tag.extract()


        # Convert HTML to plain text using html2text
        text_content = html2text.html2text(str(soup))
        return text_content

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return f"Error fetching data from {url}: {e}"

# %%
extract_html_from_url("https://iiitl.ac.in/")
# Out:
# '[__](https://mail.google.com/a/iiitl.ac.in\n"email")[__](https://www.facebook.com/Indian-Institute-of-Information-\nTechnology-Lucknow-IIITL-101698791377071\n"facebook")[__](https://www.linkedin.com/school/iiitl/\n"linkedin")[__](https://twitter.com/iiit_lucknow\n"twitter")[__](https://www.instagram.com/iiitlucknow/ "instagram")\n\n[](https://iiitl.ac.in/)\n\n__\n\n__\n\n__\n\n  * [Home](https://iiitl.ac.in/)\n    * [Director’s Desk](https://iiitl.ac.in/index.php/directorate/)\n    * [At a Glance](https://iiitl.ac.in/index.php/at-a-glance/)\n    * [IIIT Coordination Forum](http://www.iiits.ac.in/secretariat-of-iiit-ppp-coordination-forum/)\n    * [Board of Governors](https://iiitl.ac.